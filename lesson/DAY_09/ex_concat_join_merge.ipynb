# %% [markdown]
# ## [ 데이터 병합/연결/조인 ]
# - 여러 개의 Series/DataFrame 객체의 데이터들을 연결 합치기 방법

# %% [markdown]
# (1) 모듈로딩

# %%
import pandas as pd

# %% [markdown]
# (2) 데이터 준비

# %%
datas = {'name':[" 홍 길동", "이 나영", "마 징가", "베 토벤"], 
         "age":[10, 21, 73, 89],
         "reg_date":['2000/01/23', '2020/11/8', '1999/5/4', '1987/12/23']}

datas2 = [[" 홍 길동", "이 나영", "마 징가", "베 토벤"], 
         [10, 21, 73, 89],
         ['2000/01/23', '2020/11/8', '1999/5/4', '1987/12/23']]

# %% [markdown]
# (3) 데이터 저장

# %%
# Dict ==> DataFrame
df1 = pd.DataFrame(datas)
df1
# Out:
#     name  age    reg_date
# 0   홍 길동   10  2000/01/23
# 1   이 나영   21   2020/11/8
# 2   마 징가   73    1999/5/4
# 3   베 토벤   89  1987/12/23

# %%
# List ==> DataFrame
df2 = pd.DataFrame(datas2)
df2
# Out:
#             0          1         2           3
# 0        홍 길동       이 나영      마 징가        베 토벤
# 1          10         21        73          89
# 2  2000/01/23  2020/11/8  1999/5/4  1987/12/23

# %% [markdown]
# (4) 데이터 정보 확인

# %%
# 데이터의 전체 기본 정보 => info()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
#  2   2       3 non-null      object
#  3   3       3 non-null      object
# dtypes: object(4)
# memory usage: 224.0+ bytes

# %% [markdown]
# (5) 데이터 전처리

# %% [markdown]
# - (5-1) 행 <=> 열 치환

# %%
df2 = df2.T
df2
# Out:
#        0   1           2
# 0   홍 길동  10  2000/01/23
# 1   이 나영  21   2020/11/8
# 2   마 징가  73    1999/5/4
# 3   베 토벤  89  1987/12/23

# %% [markdown]
# - (5-2) 실제 데이터와 타입 확인 후 형변환

# %%
df2.head()
# Out:
#        0   1           2
# 0   홍 길동  10  2000/01/23
# 1   이 나영  21   2020/11/8
# 2   마 징가  73    1999/5/4
# 3   베 토벤  89  1987/12/23

# %%
# 1번 컬럼 : object => 정수
df2[1]=df2[1].astype('uint8')

# %%
df2.dtypes
# Out:
# 0    object
# 1     uint8
# 2    object
# dtype: object

# %%
# 2번 컬럼 : object => datetime64[ns]
df2[2]=df2[2].astype('datetime64[ns]')

# %%
df2.dtypes
# Out:
# 0            object
# 1             uint8
# 2    datetime64[ns]
# dtype: object

# %% [markdown]
# - (5-3) 0번 컬럼의 이름을 성과 이름으로 분리하기

# %%
# 0번 컬럼만 추출 => Series
nameSR = df2[0]
nameSR
# Out:
# 0     홍 길동
# 1     이 나영
# 2     마 징가
# 3     베 토벤
# Name: 0, dtype: object

# %%
# "이 나영" 데이터를 추출 => 성과 이름으로 분리
nameSR[1]
# Out:
# '이 나영'

# %%
namesDF = nameSR.str.split(expand=True)
namesDF
# Out:
#    0   1
# 0  홍  길동
# 1  이  나영
# 2  마  징가
# 3  베  토벤

# %% [markdown]
# - (5-4) 두개의 DatafFrame을 컬럼방향으로 연결

# %%
pd.concat([df2, namesDF], axis='columns', ignore_index=True)
# Out:
#        0   1          2  3   4
# 0   홍 길동  10 2000-01-23  홍  길동
# 1   이 나영  21 2020-11-08  이  나영
# 2   마 징가  73 1999-05-04  마  징가
# 3   베 토벤  89 1987-12-23  베  토벤

# %% [markdown]
# - (5-5) 두개의 DataFrame을 행(row) 방향 데이터 연결

# %%
# 여러 개의 DF, SR을 연결 시에 모든 컬럼명/행인덱스만 연결 시켜주는 방식 ==> outer 방식
pd.concat([df2, namesDF])
# Out:
#        0   1          2
# 0   홍 길동  10 2000-01-23
# 1   이 나영  21 2020-11-08
# 2   마 징가  73 1999-05-04
# 3   베 토벤  89 1987-12-23
# 0      홍  길동        NaT
# 1      이  나영        NaT
# 2      마  징가        NaT
# 3      베  토벤        NaT

# %%
# 여러 개의 DF, SR을 연결 시에 동일 컬럼명/행인덱스만 연결 시켜주는 방식 ==> inner 방식
pd.concat([df2, namesDF], join='inner')
# Out:
#        0   1
# 0   홍 길동  10
# 1   이 나영  21
# 2   마 징가  73
# 3   베 토벤  89
# 0      홍  길동
# 1      이  나영
# 2      마  징가
# 3      베  토벤

# %%
df2.append(namesDF)        # FutureWarning
# Out:
# C:\Users\kdp\AppData\Local\Temp\ipykernel_21148\3120460443.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2.append(namesDF)        # FutureWarning
#        0   1          2
# 0   홍 길동  10 2000-01-23
# 1   이 나영  21 2020-11-08
# 2   마 징가  73 1999-05-04
# 3   베 토벤  89 1987-12-23
# 0      홍  길동        NaT
# 1      이  나영        NaT
# 2      마  징가        NaT
# 3      베  토벤        NaT

# %% [markdown]
# ### [ 병합 - (2) merge]
# - 두 개의 DF에서 특정 컬럼을 기준으로 데이터를 합치는 것
# - 두 DF의 합치는 기준이 되는 컬럼을 지정 필요
# - 지정된 컬럼명이 없으면 동일한 컬럼명을 기준으로 합쳐짐

# %% [markdown]
# - (2-1) 데이터 준비

# %%
f1 = '../DATA/stock price.xlsx'
f2 = '../DATA/stock valuation.xlsx'

# %% [markdown]
# - (2-2) 데이터 저장 EXCEL ==> DataFrame

# %%
df1 = pd.read_excel(f1)
df2 = pd.read_excel(f2)

# %% [markdown]
# - (2-3) 데이터 확인

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          13 non-null     int64
#  1   stock_name  13 non-null     object
#  2   value       11 non-null     float64
#  3   price       11 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 544.0+ bytes

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10 non-null     int64
#  1   name    10 non-null     object
#  2   eps     10 non-null     float64
#  3   bps     10 non-null     int64
#  4   per     10 non-null     float64
#  5   pbr     10 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 608.0+ bytes

# %% [markdown]
# - (2-4) 데이터프레임 병합

# %% [markdown]
# - (2-4-1) merge()

# %%
# [기본] 두 개의 DF에서 동일 컬럼명을 찾아서 두 DF에 존재하는 컬럼명의 행 데이터만 합치기
pd.merge(df1, df2)
# Out:
#        id stock_name          value     price       name           eps  \
# 0  138040    메리츠금융지주     827.500000       NaN    메리츠금융지주   2122.333333
# 1  130960     CJ E&M   58540.666667   98900.0     CJ E&M   6301.333333
# 2  139480        이마트  239230.833333  254500.0        이마트  18268.166667
# 3  145990        삼양사   82750.000000   82000.0        삼양사   5741.000000
# 4  181710  NHN엔터테인먼트            NaN       NaN  NHN엔터테인먼트   2110.166667
# 5  185750        종근당   40293.666667  100500.0        종근당   3990.333333
# 6  204210     모두투어리츠    3093.333333    3475.0     모두투어리츠     85.166667
# 7  207940   삼성바이오로직스            NaN   91900.0   삼성바이오로직스   4644.166667
#
#       bps        per       pbr
# 0   14894   6.313806  0.899691
# 1   54068  15.695091  1.829178
# 2  295780  13.931338  0.860437
# 3  108090  14.283226  0.758627
# 4   78434  30.755864  0.827447
# 5   40684  25.185866  2.470259
# 6    5335  40.802348  0.651359
# 7   60099  89.790059  6.938551

# %%
# [설정 => how 'outer' ] 두 개의 DF에서 동일 컬럼명을 찾아서 모두 합치기
pd.merge(df1, df2, how='outer')
# Out:
#         id stock_name          value     price       name           eps  \
# 0   128940       한미약품   59385.666667  421000.0        NaN           NaN
# 1   138040    메리츠금융지주     827.500000       NaN    메리츠금융지주   2122.333333
# 2   130960     CJ E&M   58540.666667   98900.0     CJ E&M   6301.333333
# 3   138250      엔에스쇼핑   14558.666667   13200.0        NaN           NaN
# 4   139480        이마트  239230.833333  254500.0        이마트  18268.166667
# 5   142280     녹십자엠에스     468.833333   10200.0        NaN           NaN
# 6   145990        삼양사   82750.000000   82000.0        삼양사   5741.000000
# 7   181710  NHN엔터테인먼트            NaN       NaN  NHN엔터테인먼트   2110.166667
# 8   185750        종근당   40293.666667  100500.0        종근당   3990.333333
# 9   192400      쿠쿠홀딩스  179204.666667  177500.0        NaN           NaN
# 10  199800         툴젠   -2514.333333  115400.0        NaN           NaN
# 11  204210     모두투어리츠    3093.333333    3475.0     모두투어리츠     85.166667
# 12  207940   삼성바이오로직스            NaN   91900.0   삼성바이오로직스   4644.166667
# 13  136480        NaN            NaN       NaN         하림    274.166667
# 14  161390        NaN            NaN       NaN      한국타이어   5648.500000
#
#          bps        per       pbr
# 0        NaN        NaN       NaN
# 1    14894.0   6.313806  0.899691
# 2    54068.0  15.695091  1.829178
# 3        NaN        NaN       NaN
# 4   295780.0  13.931338  0.860437
# 5        NaN        NaN       NaN
# 6   108090.0  14.283226  0.758627
# 7    78434.0  30.755864  0.827447
# 8    40684.0  25.185866  2.470259
# 9        NaN        NaN       NaN
# 10       NaN        NaN       NaN
# 11    5335.0  40.802348  0.651359
# 12   60099.0  89.790059  6.938551
# 13    3551.0  11.489362  0.887074
# 14   51341.0   7.453306  0.820007

# %%
# [설정 => how 'left' ] 두 개의 DF에서 동일 컬럼명을 찾아서 왼쪽 DF를 기준으로 합치기
pd.merge(df1, df2, how='left')
# Out:
#         id stock_name          value     price       name           eps  \
# 0   128940       한미약품   59385.666667  421000.0        NaN           NaN
# 1   138040    메리츠금융지주     827.500000       NaN    메리츠금융지주   2122.333333
# 2   130960     CJ E&M   58540.666667   98900.0     CJ E&M   6301.333333
# 3   138250      엔에스쇼핑   14558.666667   13200.0        NaN           NaN
# 4   139480        이마트  239230.833333  254500.0        이마트  18268.166667
# 5   142280     녹십자엠에스     468.833333   10200.0        NaN           NaN
# 6   145990        삼양사   82750.000000   82000.0        삼양사   5741.000000
# 7   181710  NHN엔터테인먼트            NaN       NaN  NHN엔터테인먼트   2110.166667
# 8   185750        종근당   40293.666667  100500.0        종근당   3990.333333
# 9   192400      쿠쿠홀딩스  179204.666667  177500.0        NaN           NaN
# 10  199800         툴젠   -2514.333333  115400.0        NaN           NaN
# 11  204210     모두투어리츠    3093.333333    3475.0     모두투어리츠     85.166667
# 12  207940   삼성바이오로직스            NaN   91900.0   삼성바이오로직스   4644.166667
#
#          bps        per       pbr
# 0        NaN        NaN       NaN
# 1    14894.0   6.313806  0.899691
# 2    54068.0  15.695091  1.829178
# 3        NaN        NaN       NaN
# 4   295780.0  13.931338  0.860437
# 5        NaN        NaN       NaN
# 6   108090.0  14.283226  0.758627
# 7    78434.0  30.755864  0.827447
# 8    40684.0  25.185866  2.470259
# 9        NaN        NaN       NaN
# 10       NaN        NaN       NaN
# 11    5335.0  40.802348  0.651359
# 12   60099.0  89.790059  6.938551

# %%
# [설정 => how 'right' ] 두 개의 DF에서 동일 컬럼명을 찾아서 오른쪽 DF를 기준으로 합치기
pd.merge(df1, df2, how='right')
# Out:
#        id stock_name          value     price       name           eps  \
# 0  130960     CJ E&M   58540.666667   98900.0     CJ E&M   6301.333333
# 1  136480        NaN            NaN       NaN         하림    274.166667
# 2  138040    메리츠금융지주     827.500000       NaN    메리츠금융지주   2122.333333
# 3  139480        이마트  239230.833333  254500.0        이마트  18268.166667
# 4  145990        삼양사   82750.000000   82000.0        삼양사   5741.000000
# 5  161390        NaN            NaN       NaN      한국타이어   5648.500000
# 6  181710  NHN엔터테인먼트            NaN       NaN  NHN엔터테인먼트   2110.166667
# 7  185750        종근당   40293.666667  100500.0        종근당   3990.333333
# 8  204210     모두투어리츠    3093.333333    3475.0     모두투어리츠     85.166667
# 9  207940   삼성바이오로직스            NaN   91900.0   삼성바이오로직스   4644.166667
#
#       bps        per       pbr
# 0   54068  15.695091  1.829178
# 1    3551  11.489362  0.887074
# 2   14894   6.313806  0.899691
# 3  295780  13.931338  0.860437
# 4  108090  14.283226  0.758627
# 5   51341   7.453306  0.820007
# 6   78434  30.755864  0.827447
# 7   40684  25.185866  2.470259
# 8    5335  40.802348  0.651359
# 9   60099  89.790059  6.938551

# %%
# [설정 => how 'cross' ] 두 개의 DF에서 
pd.merge(df1, df2, how='cross')
# Out:
#        id_x stock_name         value     price    id_y       name  \
# 0    128940       한미약품  59385.666667  421000.0  130960     CJ E&M
# 1    128940       한미약품  59385.666667  421000.0  136480         하림
# 2    128940       한미약품  59385.666667  421000.0  138040    메리츠금융지주
# 3    128940       한미약품  59385.666667  421000.0  139480        이마트
# 4    128940       한미약품  59385.666667  421000.0  145990        삼양사
# ..      ...        ...           ...       ...     ...        ...
# 125  207940   삼성바이오로직스           NaN   91900.0  161390      한국타이어
# 126  207940   삼성바이오로직스           NaN   91900.0  181710  NHN엔터테인먼트
# 127  207940   삼성바이오로직스           NaN   91900.0  185750        종근당
# 128  207940   삼성바이오로직스           NaN   91900.0  204210     모두투어리츠
# 129  207940   삼성바이오로직스           NaN   91900.0  207940   삼성바이오로직스
#
#               eps     bps        per       pbr
# 0     6301.333333   54068  15.695091  1.829178
# 1      274.166667    3551  11.489362  0.887074
# 2     2122.333333   14894   6.313806  0.899691
# 3    18268.166667  295780  13.931338  0.860437
# 4     5741.000000  108090  14.283226  0.758627
# ..            ...     ...        ...       ...
# 125   5648.500000   51341   7.453306  0.820007
# 126   2110.166667   78434  30.755864  0.827447
# 127   3990.333333   40684  25.185866  2.470259
# 128     85.166667    5335  40.802348  0.651359
# 129   4644.166667   60099  89.790059  6.938551
#
# [130 rows x 10 columns]

# %%
idsr = df1.id
valuesr = df1.value

# %%
pd.concat([df1, idsr])
# Out:
#           id stock_name          value     price         0
# 0   128940.0       한미약품   59385.666667  421000.0       NaN
# 1   138040.0    메리츠금융지주     827.500000       NaN       NaN
# 2   130960.0     CJ E&M   58540.666667   98900.0       NaN
# 3   138250.0      엔에스쇼핑   14558.666667   13200.0       NaN
# 4   139480.0        이마트  239230.833333  254500.0       NaN
# 5   142280.0     녹십자엠에스     468.833333   10200.0       NaN
# 6   145990.0        삼양사   82750.000000   82000.0       NaN
# 7   181710.0  NHN엔터테인먼트            NaN       NaN       NaN
# 8   185750.0        종근당   40293.666667  100500.0       NaN
# 9   192400.0      쿠쿠홀딩스  179204.666667  177500.0       NaN
# 10  199800.0         툴젠   -2514.333333  115400.0       NaN
# 11  204210.0     모두투어리츠    3093.333333    3475.0       NaN
# 12  207940.0   삼성바이오로직스            NaN   91900.0       NaN
# 0        NaN        NaN            NaN       NaN  128940.0
# 1        NaN        NaN            NaN       NaN  138040.0
# 2        NaN        NaN            NaN       NaN  130960.0
# 3        NaN        NaN            NaN       NaN  138250.0
# 4        NaN        NaN            NaN       NaN  139480.0
# 5        NaN        NaN            NaN       NaN  142280.0
# 6        NaN        NaN            NaN       NaN  145990.0
# 7        NaN        NaN            NaN       NaN  181710.0
# 8        NaN        NaN            NaN       NaN  185750.0
# 9        NaN        NaN            NaN       NaN  192400.0
# 10       NaN        NaN            NaN       NaN  199800.0
# 11       NaN        NaN            NaN       NaN  204210.0
# 12       NaN        NaN            NaN       NaN  207940.0

# %%
pd.concat([valuesr, idsr], join='inner', axis=1)
# Out:
#             value      id
# 0    59385.666667  128940
# 1      827.500000  138040
# 2    58540.666667  130960
# 3    14558.666667  138250
# 4   239230.833333  139480
# 5      468.833333  142280
# 6    82750.000000  145990
# 7             NaN  181710
# 8    40293.666667  185750
# 9   179204.666667  192400
# 10   -2514.333333  199800
# 11    3093.333333  204210
# 12            NaN  207940

# %%
pd.concat([df1.iloc[0], df1.iloc[1]], join='inner')
# Out:
# id                  128940
# stock_name            한미약품
# value         59385.666667
# price             421000.0
# id                  138040
# stock_name         메리츠금융지주
# value                827.5
# price                  NaN
# dtype: object

# %%
df1.iloc[0]
# Out:
# id                  128940
# stock_name            한미약품
# value         59385.666667
# price             421000.0
# Name: 0, dtype: object

# %%
pd.DataFrame(df1.iloc[0]).T
# Out:
#        id stock_name         value     price
# 0  128940       한미약품  59385.666667  421000.0

# %%
pd.concat([df1.iloc[0], df1.iloc[1]], join='inner', axis=1).T
# Out:
#        id stock_name         value     price
# 0  128940       한미약품  59385.666667  421000.0
# 1  138040    메리츠금융지주         827.5       NaN

# %%
pd.concat([df1.iloc[0], df1])
# Out:
#                        0        id stock_name          value     price
# id                128940       NaN        NaN            NaN       NaN
# stock_name          한미약품       NaN        NaN            NaN       NaN
# value       59385.666667       NaN        NaN            NaN       NaN
# price           421000.0       NaN        NaN            NaN       NaN
# 0                    NaN  128940.0       한미약품   59385.666667  421000.0
# 1                    NaN  138040.0    메리츠금융지주     827.500000       NaN
# 2                    NaN  130960.0     CJ E&M   58540.666667   98900.0
# 3                    NaN  138250.0      엔에스쇼핑   14558.666667   13200.0
# 4                    NaN  139480.0        이마트  239230.833333  254500.0
# 5                    NaN  142280.0     녹십자엠에스     468.833333   10200.0
# 6                    NaN  145990.0        삼양사   82750.000000   82000.0
# 7                    NaN  181710.0  NHN엔터테인먼트            NaN       NaN
# 8                    NaN  185750.0        종근당   40293.666667  100500.0
# 9                    NaN  192400.0      쿠쿠홀딩스  179204.666667  177500.0
# 10                   NaN  199800.0         툴젠   -2514.333333  115400.0
# 11                   NaN  204210.0     모두투어리츠    3093.333333    3475.0
# 12                   NaN  207940.0   삼성바이오로직스            NaN   91900.0

# %%
df3 = pd.DataFrame([[100]])
df3
# Out:
#      0
# 0  100

# %%
pd.concat([pd.DataFrame(df1.iloc[0]).T, df3], axis=0)
# Out:
#        id stock_name         value     price      0
# 0  128940       한미약품  59385.666667  421000.0    NaN
# 0     NaN        NaN           NaN       NaN  100.0

# %%
pd.concat([pd.DataFrame(df1.iloc[0]).T, df3], axis=1)
# Out:
#        id stock_name         value     price    0
# 0  128940       한미약품  59385.666667  421000.0  100

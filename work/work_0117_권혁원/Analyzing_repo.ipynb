# %%
import matplotlib.pyplot as plt                # 그래프 관련 모듈
import matplotlib as mpl                       # 패키지 관련
import matplotlib.font_manager as fm           # 패키지 리소스 즉 자원 중 폰트 관련 모듈
import pandas as pd
import numpy as np

# %%
repo = pd.read_json('./repo.json')
repo
# Out:
#      id                   node_id                    name  \
# 0     1      MDEwOlJlcG9zaXRvcnkx                    grit
# 1    26  MDEwOlJlcG9zaXRvcnkyNg==               merb-core
# 2    27  MDEwOlJlcG9zaXRvcnkyNw==                rubinius
# 3    28  MDEwOlJlcG9zaXRvcnkyOA==                     god
# 4    29  MDEwOlJlcG9zaXRvcnkyOQ==               jsawesome
# ..  ...                       ...                     ...
# 95  364  MDEwOlJlcG9zaXRvcnkzNjQ=      acts_as_geocodable
# 96  365  MDEwOlJlcG9zaXRvcnkzNjU=           acts_as_money
# 97  367  MDEwOlJlcG9zaXRvcnkzNjc=        calendar_builder
# 98  368  MDEwOlJlcG9zaXRvcnkzNjg=  clear_empty_attributes
# 99  369  MDEwOlJlcG9zaXRvcnkzNjk=           css_naked_day
#
#                                 full_name  private  \
# 0                            mojombo/grit    False
# 1                        wycats/merb-core    False
# 2                       rubinius/rubinius    False
# 3                             mojombo/god    False
# ...

# %%
repoNormal = pd.json_normalize(repo.owner)
repoNormal
# Out:
#              login      id                           node_id  \
# 0          mojombo       1                      MDQ6VXNlcjE=
# 1           wycats       4                      MDQ6VXNlcjQ=
# 2         rubinius  317747  MDEyOk9yZ2FuaXphdGlvbjMxNzc0Nw==
# 3          mojombo       1                      MDQ6VXNlcjE=
# 4          vanpelt      17                      MDQ6VXNlcjE3
# ..             ...     ...                               ...
# 95  collectiveidea     128      MDEyOk9yZ2FuaXphdGlvbjEyOA==
# 96  collectiveidea     128      MDEyOk9yZ2FuaXphdGlvbjEyOA==
# 97  collectiveidea     128      MDEyOk9yZ2FuaXphdGlvbjEyOA==
# 98  collectiveidea     128      MDEyOk9yZ2FuaXphdGlvbjEyOA==
# 99  collectiveidea     128      MDEyOk9yZ2FuaXphdGlvbjEyOA==
#
#                                            avatar_url gravatar_id  \
# 0      https://avatars0.githubusercontent.com/u/1?v=4
# 1      https://avatars0.githubusercontent.com/u/4?v=4
# 2   https://avatars2.githubusercontent.com/u/31774...
# ...

# %%
repoNormal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   login                100 non-null    object
#  1   id                   100 non-null    int64
#  2   node_id              100 non-null    object
#  3   avatar_url           100 non-null    object
#  4   gravatar_id          100 non-null    object
#  5   url                  100 non-null    object
#  6   html_url             100 non-null    object
#  7   followers_url        100 non-null    object
#  8   following_url        100 non-null    object
#  9   gists_url            100 non-null    object
#  10  starred_url          100 non-null    object
#  11  subscriptions_url    100 non-null    object
#  12  organizations_url    100 non-null    object
#  13  repos_url            100 non-null    object
#  14  events_url           100 non-null    object
# ...
